# %% [markdown]
# # Welcome to Digital Image Processing
#
# **What we will learn?**
#
# *Some cool Image Processing Techniques*
#
# **The goal?**
#
# ![](Simple-OCR-Calculator\demo.gif)
#
# *To make a simple OCR calculator*
#
# **Advantages?**
#
# *Lets look under the hood of an OCR*
#
# **So, How will we do it?**
#
# *May be in 7 Lectures:*
#
# * Introduction to DIP - Getting familiar with OpenCV
#
# * Filtering in Images - Blurring and Sharpening
#
# * Image Gradients - Introduction to Sobel & The Canny Edge Detector
#
# * Image Thresholding - The OTSU thresholding
#
# * Morphological Operations & Perspective Transforms
#
# * Pattern Recognition - A Slight Introduction to DL
#
# * Putting it all Together

# %%
# !pip install numpy
# Out:
# ...
# WARNING: You are using pip version 20.2; however, version 20.2.4 is available.
# You should consider upgrading via the 'c:\users\bobstone\appdata\local\programs\python\python36\python.exe -m pip install --upgrade pip' command.

# %%
l  = [ 1, 2, 3, 4, 5]

# %%
l = [[1, 2, 3], [4, 5, 6]]

# %%
import numpy as np

# %%
np_array = np.array(l)

# %%
np_array[:, 2]
# Out:
# array([3, 6])

# %%
# !pip install opencv-python
# Out:
# ...
# WARNING: You are using pip version 20.2; however, version 20.2.4 is available.
# You should consider upgrading via the 'c:\users\bobstone\appdata\local\programs\python\python36\python.exe -m pip install --upgrade pip' command.

# %%
import cv2

# %%
image = cv2.imread("./random_image.jpg")

# %%
# !pip install matplotlib
import matplotlib.pyplot as plt

# %%
# cv2.imshow
plt.imshow(image)
plt.show()

# %%
plt.imshow(image[...,[2, 1, 0]])
plt.show()

# %%
image.shape
# Out:
# (960, 600, 3)

# %%
cv2.COLOR_BGR2RGB
# Out:
# 4

# %%
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(rgb_image)
plt.show()

# %%
image.dtype
# Out:
# dtype('uint8')

# %%
image[0, 0]
# Out:
# array([ 4,  6, 17], dtype=uint8)

# %%
red_image = np.zeros_like(image)
blue_image = np.zeros_like(image)
green_image = np.zeros_like(image)

# %%
red_image[:, :, 0] = image[:, :, 0] 
blue_image[:, :, 2] = image[:, :, 2]
blue_image[:, :, 1] = image[:, :, 1]

# %%
plt.imshow(red_image)
plt.show()
plt.imshow(blue_image)
plt.show()
plt.imshow(green_image)
plt.show()

# %%
# plt.imshow(image[:, :, 0])
# plt.show()

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

# %%
gray_image.shape
# Out:
# (960, 600)

# %%
plt.imshow(gray_image, cmap="gray")
plt.show()
