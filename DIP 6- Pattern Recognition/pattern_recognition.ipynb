# %%
from model import predict
import os
import cv2
import matplotlib.pyplot as plt
from Preprocess import preprocess

# %%
path = "./Extracted_Digits"

# %%
for img_path in [os.path.join(path, i) for i in os.listdir(path)]:
    im = cv2.imread(img_path)
    plt.imshow(im[...,[2,1,0]])
    # im = preprocess(img_path)
    plt.imshow(im, cmap="gray")
    plt.axis("off")
    plt.title("Predicted Symbol: " + predict(img_path), fontsize=20)
    plt.show()
